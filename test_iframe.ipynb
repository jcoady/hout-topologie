# %%
# %%html
# <a href="http://www.cnn.com">link</a>
# Out:
# <a href="http://www.cnn.com">link</a>

# %%
# %%html
# <iframe src="http://www.cnn.com" title="sample html file"></iframe>
# Out:
# <iframe src="http://www.cnn.com" title="sample html file"></iframe>

# %%
# %%html
# <iframe src="https://www.cnn.com" title="sample html file"></iframe>
# Out:
# <iframe src="https://www.cnn.com" title="sample html file"></iframe>

# %%
# %%html
# <iframe src="sample.html" title="sample html file"></iframe>
# Out:
# <iframe src="sample.html" title="sample html file"></iframe>
